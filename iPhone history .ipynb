# %% [markdown]
# # 整理歷年iPhone的基本資料

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
iPhone = pd.read_html("https://en.wikipedia.org/wiki/IPhone")

# %%
len(iPhone)
# Out:
# 25

# %%
iPhone1 = iPhone[3]

# %%
iPhone1.head()
# Out:
#            0              1              2               3              4  \
# 0      model     release(d)   discontinued         support   launch price
# 1    with OS           date          ended        final OS       lifespan
# 2        max            min            NaN             NaN            NaN
# 3     iPhone  iPhone OS 1.0  June 29, 2007    June 9, 2008  June 20, 2010
# 4  iPhone 3G  iPhone OS 2.0  July 11, 2008  August 9, 2010  March 3, 2011
#
#                  5                   6         7               8
# 0              NaN                 NaN       NaN             NaN
# 1              NaN                 NaN       NaN             NaN
# 2              NaN                 NaN       NaN             NaN
# 3  iPhone OS 3.1.3  2 years, 11 months   2 years      $499/$599*
# 4        iOS 4.2.1   2 years, 7 months  6 months  $199/$299*$499

# %%
iPhone2 = iPhone1.drop(0)

# %%
iPhone3 = iPhone2.drop(1)

# %%
iPhone4 = iPhone3.drop(2)

# %%
iPhone4
# Out:
#                                                     0  \
# 3                                              iPhone
# 4                                           iPhone 3G
# 5                                          iPhone 3GS
# 6                                            iPhone 4
# 7                                           iPhone 4S
# 8                                            iPhone 5
# 9                                           iPhone 5C
# 10                                          iPhone 5S
# 11                                  iPhone 6 / 6 Plus
# 12                                iPhone 6S / 6S Plus
# 13                                          iPhone SE
# 14                                  iPhone 7 / 7 Plus
# 15                                  iPhone 8 / 8 Plus
# 16                                           iPhone X
# 17                                 iPhone XS / XS Max
# 18                                          iPhone XR
# ...

# %%
iPhone5 = iPhone4.drop(21)

# %%
iPhone6 = iPhone5.drop(22)

# %%
iPhone7 = iPhone6.drop(23)

# %%
iPhone7
# Out:
#                            0              1                   2  \
# 3                     iPhone  iPhone OS 1.0       June 29, 2007
# 4                  iPhone 3G  iPhone OS 2.0       July 11, 2008
# 5                 iPhone 3GS  iPhone OS 3.0       June 19, 2009
# 6                   iPhone 4        iOS 4.0       June 21, 2010
# 7                  iPhone 4S        iOS 5.0    October 14, 2011
# 8                   iPhone 5        iOS 6.0  September 21, 2012
# 9                  iPhone 5C        iOS 7.0  September 20, 2013
# 10                 iPhone 5S        iOS 7.0  September 20, 2013
# 11         iPhone 6 / 6 Plus        iOS 8.0  September 19, 2014
# 12       iPhone 6S / 6S Plus      iOS 9.0.1  September 25, 2015
# 13                 iPhone SE        iOS 9.3      March 31, 2016
# 14         iPhone 7 / 7 Plus       iOS 10.0  September 16, 2016
# 15         iPhone 8 / 8 Plus       iOS 11.0  September 22, 2017
# 16                  iPhone X       iOS 11.1    November 3, 2017
# ...

# %%
iPhone7.columns = ['model', 'released with OS', 'released date', 'discontinued', 'support ended', 'support final OS', 'lifespan max', 'lifespan min', 'launch price']

# %%
iPhone7
# Out:
#                        model released with OS       released date  \
# 3                     iPhone    iPhone OS 1.0       June 29, 2007
# 4                  iPhone 3G    iPhone OS 2.0       July 11, 2008
# 5                 iPhone 3GS    iPhone OS 3.0       June 19, 2009
# 6                   iPhone 4          iOS 4.0       June 21, 2010
# 7                  iPhone 4S          iOS 5.0    October 14, 2011
# 8                   iPhone 5          iOS 6.0  September 21, 2012
# 9                  iPhone 5C          iOS 7.0  September 20, 2013
# 10                 iPhone 5S          iOS 7.0  September 20, 2013
# 11         iPhone 6 / 6 Plus          iOS 8.0  September 19, 2014
# 12       iPhone 6S / 6S Plus        iOS 9.0.1  September 25, 2015
# 13                 iPhone SE          iOS 9.3      March 31, 2016
# 14         iPhone 7 / 7 Plus         iOS 10.0  September 16, 2016
# 15         iPhone 8 / 8 Plus         iOS 11.0  September 22, 2017
# ...
