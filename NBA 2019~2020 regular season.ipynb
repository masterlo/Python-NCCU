# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_tmp = pd.read_html('https://global.espn.com/nba/standings/_/group/league', encoding='big5')

# %%
len(df_tmp)
# Out:
# 2

# %%
df0 = df_tmp[0]

# %%
df0.head()
# Out:
#                        0
# 0      BOSBoston Celtics
# 1  LALLos Angeles Lakers
# 2      DENDenver Nuggets
# 3     TORToronto Raptors
# 4     MILMilwaukee Bucks

# %%
df1 = df_tmp[1]

# %%
df1.head()
# Out:
#    W  L    PCT   GB HOME AWAY  DIV CONF    PPG  OPP PPG  DIFF STRK  L10
# 0  7  1  0.875    -  3-0  4-1  3-1  6-1  113.1    103.8   9.3   W7  7-1
# 1  7  2  0.778  0.5  4-1  3-1  0-1  4-1  108.4    100.1   8.3   L1  7-2
# 2  7  2  0.778  0.5  3-1  4-1  2-0  4-2  103.3    100.3   3.0   W4  7-2
# 3  7  2  0.778  0.5  4-0  3-2  0-1  3-2  115.2    107.7   7.5   W3  7-2
# 4  7  3  0.700    1  2-1  5-2  1-0  3-2  119.9    111.8   8.1   W1  7-3

# %%
df2 = pd.concat([df0, df1], axis=1)

# %%
df2
# Out:
#                             0  W  L    PCT   GB HOME AWAY  DIV CONF    PPG  \
# 0           BOSBoston Celtics  7  1  0.875    -  3-0  4-1  3-1  6-1  113.1
# 1       LALLos Angeles Lakers  7  2  0.778  0.5  4-1  3-1  0-1  4-1  108.4
# 2           DENDenver Nuggets  7  2  0.778  0.5  3-1  4-1  2-0  4-2  103.3
# 3          TORToronto Raptors  7  2  0.778  0.5  4-0  3-2  0-1  3-2  115.2
# 4          MILMilwaukee Bucks  7  3  0.700    1  2-1  5-2  1-0  3-2  119.9
# 5          HOUHouston Rockets  6  3  0.667  1.5  3-1  3-2  2-0  4-0  120.1
# 6               MIAMiami Heat  6  3  0.667  1.5  3-0  3-3  2-0  3-0  111.1
# 7               UTAHUtah Jazz  6  3  0.667  1.5  5-0  1-3  1-0  4-3  101.0
# 8       PHIPhiladelphia 76ers  6  3  0.667  1.5  3-0  3-3  1-0  4-0  111.0
# 9             PHXPhoenix Suns  6  3  0.667  1.5  4-2  2-1  3-0  4-2  116.8
# 10             LACLA Clippers  6  3  0.667  1.5  5-1  1-2  2-1  5-2  113.4
# ...

# %%
df2.describe()
# Out:
#                W          L        PCT         PPG     OPP PPG       DIFF
# count  30.000000  30.000000  30.000000   30.000000   30.000000  30.000000
# mean    4.633333   4.633333   0.504600  110.450000  110.356667   0.093333
# std     1.771096   1.991072   0.203627    6.005156    6.793388   5.817568
# min     2.000000   1.000000   0.200000   98.100000   97.000000 -11.400000
# 25%     3.000000   3.000000   0.333000  106.125000  105.975000  -4.400000
# 50%     4.500000   4.500000   0.500000  111.050000  109.650000  -0.300000
# 75%     6.000000   6.000000   0.667000  114.925000  114.250000   4.400000
# max     7.000000   8.000000   0.875000  120.100000  122.400000   9.300000
